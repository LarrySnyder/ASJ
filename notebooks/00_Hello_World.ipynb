# %% [markdown]
# <a href="https://colab.research.google.com/github/LarrySnyder/ASJ/blob/main/tutorials/00_Hello_World.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hello, World!
#
# In this tutorial, you will create your (maybe) first Python program. Everybody's favorite first program prints "Hello, world!" to the screen, and that's what yours will do too.
#
# The file you are working in right now is called a Jupyter notebook. A Jupyter notebook combines text (like this "cell"), Python code (like the cell right under this one), and the results of your code, all in one place.
#
# In the cell below this one, type
#
# ```
# print('Hello, world!')
# ```
#
# Type it exactly as it is above—don't change any of the punctuation, capitalization, etc.
#
# After you type the command, and while the cursor is still in the cell, press <kbd>`Shift`</kbd> + <kbd>`Enter`</kbd>. Alternatively, you can click the ▶ icon to the left of the cell.
#
# If you did everything correctly, the output of your code—`Hello, world!`—will appear below the cell.

# %%
print('Hello, world!')

# %% [markdown]
# Hooray!
