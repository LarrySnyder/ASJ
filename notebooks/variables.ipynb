# %% [markdown]
# <a href="https://colab.research.google.com/github/LarrySnyder/ASJ/blob/main/notebooks/variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Welcome back!**
#
# Let's do a little more Pythoning.

# %% [markdown]
# # Variables

# %% [markdown]
# ## Creating Variables
#
# All programming languages, including Python, use **variables** as a way to store information. In the cell below, replace the `...` with
#
# ```
# a = 42
# ```
#
# and **execute** the cell (press <kbd>`Shift`</kbd> + <kbd>`Return`</kbd> or click the ▶ icon to the left of the cell).

# %%
...

# %% [markdown]
# You didn't get any output because you didn't ask Python for any. You can ask Python to print the value of `a` using either
#
# ```
# print(a)
# ```
#
# or just
#
# ```
# a
# ```
# Try it.

# %%
...

# %% [markdown]
# ---

# %% [markdown]
# ## Working with Variables
#
# We can do math using variables. For example, type
#
# ```
# print(a + 5)
# ```
#
# in the cell below, and execute it.

# %%
...

# %% [markdown]
# ---

# %% [markdown]
# One really useful thing about variables is that you can change them. (That's why they're called *variables*!) Try this:
#
# ```
# a = 37
# print(a)
# ```
#
# ---
# > 👓 **Note:** In Python, an equal sign `=` means "*assign* the value on the right to the variable on the left." It does *not* mean "the variable on the left *is equal to* the value on the right."
# ---

# %%
...

# %% [markdown]
# ---

# %% [markdown]
# And of course, you can set the value of variables based on the values of other variables. Type this:
#
# ```
# a = 10
# b = 4
# x = a + b
# print(x)
# ```
#
# What do you expect the output to be?
#
# Try it. Were you right?

# %%
...

# %% [markdown]
# You can also change the value of a variable based on itself. What do you expect the following code to produce?
#
# ```
# a = 4
# a = a * 2
# print(a)
# ```
#
# (In Python and most other programming languages, `*` means "times" and `/` means "divide.")
#
# Try it. Were you right?

# %%
...

# %% [markdown]
# ---

# %% [markdown]
# ## Naming Variables
#
# Variables don't have to have single-character names. In fact, it's often better to use longer, more descriptive names:
#
# ```
# radius = 5
# pi = 3.14
# circumference = 2 * pi * radius
# print(circumference)
# ```
#
# Try it.

# %%
...

# %% [markdown]
# Variable names can contain underscores (`_`) and digits but not dashes or other special characters. The following are all fine:
#
# * `name_of_file`
# * `number_of_rows`
# * `my_variable_2`
#
# You don't *need* the underscores. Python will *allow* you to create variables like `numberofrows`, but best practices say that it's better to use underscores, for readability.

# %% [markdown]
# ## Errors
#
# Python, like most programming languaes, can be pretty finnicky when it comes to **syntax.** If you miss a parenthesis or add an extraneous comma or make any number of other mistakes, Python will yell at you by displaying an **error message.**
#
# Try it: In the cell below, type
#
# ```
# print(a
# ```
#
# (Note that there's no close-parenthesis. If Colab adds one for you automatically, delete it.)

# %%
...

# %% [markdown]
# Python makes it crystal clear that *something* is wrong, but it can be pretty cryptic about *what*, exactly, the problem is. In this case it's obvious (we made the mistake on purpose, after all). In the future, it might be easy for you to fix your errors, or it might take some effort. (This is called **debugging** and is part of every programmer's daily life, for better or for worse.) If all else fails, your instructor or TA can help.
#
# And these are the easy errors (!!) because Python points them out to you. Other errors (**bugs**) arise from mistakes in your logic. In that case, you have provided valid instructions to Python, and Python has executed your instructions correctly, but you gave it the wrong instructions to begin with.

# %% [markdown]
# ## Your Turn!

# %% [markdown]
# 1. Define a variable called `r`, set it equal to 100, and print its value.

# %%
...

# %% [markdown]
# 2. Define 3 variables, called `height1`, `height2`, and `height3`. Assign values to each (representing a person's height in inches). Print the average height among the 3 people. (*Hint*: To calculate an average, add up the items *inside parentheses*, then divide by the number of items.)

# %%
...

# %% [markdown]
# 3. What do you think will be the output of the following code? Make a guess, type the code, execute it, and check your guess.
#
# ```
# m = 6
# n = 2
# k = m * n
# k = k + 5
# p = k - n
# print(p)
# ```

# %%
...
